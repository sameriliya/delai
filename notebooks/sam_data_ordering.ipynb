# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../raw_data/train_subset_processed_5m.csv')
data.head()
# Out:
#    y_2018  y_2019  y_2020  y_2021  y_2022  dist_scaled       sin_dow  cos_dow  \
# 0       0       0       0       1       0     0.178399 -2.449294e-16      1.0
# 1       0       0       0       1       0     0.171498 -2.449294e-16      1.0
# 2       0       0       0       1       0     0.026915 -2.449294e-16      1.0
# 3       0       0       0       0       1     0.101104 -2.449294e-16      1.0
# 4       0       0       0       0       1     0.028986 -2.449294e-16      1.0
#
#     sin_dom   cos_dom  ...  sin_qua       cos_qua   sin_dep   cos_dep  \
# 0 -0.571268  0.820763  ...      1.0  6.123234e-17  0.220697 -0.975342
# 1 -0.571268  0.820763  ...      1.0  6.123234e-17 -0.122735 -0.992439
# 2 -0.571268  0.820763  ...      1.0  6.123234e-17  0.918791 -0.394744
# 3 -0.790776 -0.612106  ...      1.0  6.123234e-17 -0.490904  0.871214
# 4 -0.790776 -0.612106  ...      1.0  6.123234e-17  0.500000 -0.866025
#
#     sin_arr   cos_arr  Marketing_Airline_Network  Origin Dest  y
# ...

# %%
data = data.sample(frac = 1)
data
# Out:
#          y_2018  y_2019  y_2020  y_2021  y_2022  dist_scaled       sin_dow  \
# 171261        0       0       0       0       1     0.130262  9.749279e-01
# 1069291       0       0       0       1       0     0.051587  4.338837e-01
# 2609279       0       0       0       0       1     0.067460 -2.449294e-16
# 515373        0       0       0       0       1     0.107660 -2.449294e-16
# 4810935       0       0       0       0       1     0.076777 -9.749279e-01
# ...         ...     ...     ...     ...     ...          ...           ...
# 4614097       0       0       0       1       0     0.443754 -4.338837e-01
# 3803141       0       0       0       0       1     0.017771  7.818315e-01
# 2335419       0       0       0       0       1     0.018461 -4.338837e-01
# 3829596       0       0       0       1       0     0.285369  7.818315e-01
# 1175151       0       0       0       0       1     0.070566 -4.338837e-01
#
# ...

# %%
data = data.reset_index().drop(columns = ['index'])

# %%
data = data.reset_index()

# %%
data.head()
# Out:
#    index  y_2018  y_2019  y_2020  y_2021  y_2022  dist_scaled       sin_dow  \
# 0      0       0       0       0       0       1     0.130262  9.749279e-01
# 1      1       0       0       0       1       0     0.051587  4.338837e-01
# 2      2       0       0       0       0       1     0.067460 -2.449294e-16
# 3      3       0       0       0       0       1     0.107660 -2.449294e-16
# 4      4       0       0       0       0       1     0.076777 -9.749279e-01
#
#     cos_dow   sin_dom  ...       sin_qua       cos_qua   sin_dep  \
# 0 -0.222521  0.201299  ...  1.000000e+00  6.123234e-17 -0.872496
# 1 -0.900969 -0.299363  ...  1.000000e+00  6.123234e-17 -1.000000
# 2  1.000000  0.848644  ...  1.224647e-16 -1.000000e+00  0.488621
# 3  1.000000 -0.724793  ...  1.000000e+00  6.123234e-17  0.858065
# 4 -0.222521  0.485302  ...  1.224647e-16 -1.000000e+00 -0.382683
#
#         cos_dep   sin_arr   cos_arr  Marketing_Airline_Network  Origin  Dest  \
# ...

# %%
data.to_csv('../raw_data/train_subset_processed_5m_indexed.csv', index = False)
