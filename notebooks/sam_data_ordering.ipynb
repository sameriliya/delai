# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../raw_data/val_subset_2021_2022.csv')
data.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  CRSDepTime  CRSArrTime  \
# 0  2021        1      1          23          6        1243        1531
# 1  2021        1      1          23          6        1745        1844
# 2  2022        1      1          24          1        1632        1940
# 3  2021        1      1           5          2         601         834
# 4  2022        1      1          16          7        1152        1319
#
#   Marketing_Airline_Network Origin Dest  Distance  ArrDelayMinutes  Cancelled  \
# 0                        AA    ABQ  DFW       569              0.0      False
# 1                        AA    ACT  DFW        89             24.0      False
# 2                        AA    AEX  CLT       722              0.0      False
# 3                        AA    ALB  CLT       646              0.0      False
# 4                        AA    ALB  DCA       318              7.0      False
#
#    Diverted
# 0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
data = data.sample(frac = 1)
data
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  CRSDepTime  CRSArrTime  \
# 1859458  2022        2      6          24          5        2005        2130
# 930048   2021        3      8           9          1         800         846
# 31074    2022        1      1           2          7        1002        1158
# 1919821  2022        3      7          27          3        1204        1942
# 860761   2021        3      7          18          7        2137        2316
# ...       ...      ...    ...         ...        ...         ...         ...
# 1208740  2021        1      2           4          4        1100        1150
# 1379423  2022        2      5          13          5        1711        1956
# 1624183  2021        3      8          17          2        1125        1240
# 821767   2022        3      7           9          6        1130        1359
# 1335026  2022        2      4          26          2        2015        2155
#
# ...

# %%
data = data.reset_index().drop(columns = ['index'])

# %%
# data = data.head(2000000)
# data
# Out:
#            index  Year  Quarter  Month  DayofMonth  DayOfWeek  CRSDepTime  \
# 0              0  2022        2      6          24          5        2005
# 1              1  2021        3      8           9          1         800
# 2              2  2022        1      1           2          7        1002
# 3              3  2022        3      7          27          3        1204
# 4              4  2021        3      7          18          7        2137
# ...          ...   ...      ...    ...         ...        ...         ...
# 1999995  1999995  2021        1      2           9          2        1145
# 1999996  1999996  2021        3      8           4          3        1511
# 1999997  1999997  2021        3      9          27          1         805
# 1999998  1999998  2022        3      7          17          7        1400
# 1999999  1999999  2022        2      5           2          1        1205
#
#          CRSArrTime Marketing_Airline_Network Origin Dest  Distance  \
# ...

# %%
data = data.drop(columns = 'index')

# %%
data.to_csv('../raw_data/val_subset_2m.csv', index = False)
