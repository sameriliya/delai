# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../raw_data/train_subset_balanced_initial_3m.csv')
data
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  CRSDepTime  CRSArrTime  \
# 0        2019        1      1           1          2        1905        2135
# 1        2019        1      1           1          2        1041        1103
# 2        2018        1      1           1          1        1209        1425
# 3        2022        1      1           1          6        2026        2218
# 4        2022        1      1           1          6        1927        2117
# ...       ...      ...    ...         ...        ...         ...         ...
# 3199995  2021        4     12          31          5         745        1040
# 3199996  2019        4     12          31          2        2002        2113
# 3199997  2019        4     12          31          2        1945        2113
# 3199998  2019        4     12          31          2        1325        1551
# 3199999  2021        4     12          31          5         740         945
#
# ...

# %%
data_shuffled = data.sample(frac=1).reset_index(drop=True)
data_shuffled
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  CRSDepTime  CRSArrTime  \
# 0        2021        4     10          19          2         800        1640
# 1        2019        3      9          26          4        1947        2117
# 2        2022        2      5          13          5         715        1215
# 3        2021        4     10          13          3         508         710
# 4        2019        3      9          29          7        1816        1924
# ...       ...      ...    ...         ...        ...         ...         ...
# 3199995  2019        1      2          10          7         740         910
# 3199996  2019        3      9          12          4        1847        2139
# 3199997  2019        1      2          19          2         600         837
# 3199998  2019        2      4           5          5         710        1107
# 3199999  2019        2      5          28          2        1500        1610
#
# ...

# %%
data_shuffled.to_csv('../raw_data/train_subset_balanced_3m.csv', index = False)
