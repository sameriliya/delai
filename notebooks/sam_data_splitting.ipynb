# %%
import pandas as pd
import numpy as np

# %%
comb = pd.read_csv('../raw_data/combined_subset.csv')

# %%
comb
# Out:
#           Unnamed: 0  FlightDate  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0                  0  2018-01-23  2018        1      1          23          2
# 1                  1  2018-01-24  2018        1      1          24          3
# 2                  2  2018-01-25  2018        1      1          25          4
# 3                  3  2018-01-26  2018        1      1          26          5
# 4                  4  2018-01-27  2018        1      1          27          6
# ...              ...         ...   ...      ...    ...         ...        ...
# 29193777    29193777  2022-03-31  2022        1      3          31          4
# 29193778    29193778  2022-03-17  2022        1      3          17          4
# 29193779    29193779  2022-03-08  2022        1      3           8          2
# 29193780    29193780  2022-03-25  2022        1      3          25          5
# 29193781    29193781  2022-03-07  2022        1      3           7          1
#
# ...

# %%
train_val = comb.sample(frac=0.7)
train_val
# Out:
#           Unnamed: 0  FlightDate  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 8997246      8997246  2019-09-20  2019        3      9          20          5
# 16345357    16345357  2020-07-08  2020        3      7           8          3
# 17379892    17379892  2020-08-15  2020        3      8          15          6
# 2082529      2082529  2018-12-25  2018        4     12          25          2
# 11458127    11458127  2019-05-15  2019        2      5          15          3
# ...              ...         ...   ...      ...    ...         ...        ...
# 27898805    27898805  2022-06-10  2022        2      6          10          5
# 25713834    25713834  2022-02-19  2022        1      2          19          6
# 8249967      8249967  2019-06-06  2019        2      6           6          4
# 26532614    26532614  2022-07-20  2022        3      7          20          3
# 3176043      3176043  2018-04-27  2018        2      4          27          5
#
# ...

# %%
test = comb[~comb.index.isin(train_val.index)]

# %%
test
# Out:
#           Unnamed: 0  FlightDate  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 0                  0  2018-01-23  2018        1      1          23          2
# 3                  3  2018-01-26  2018        1      1          26          5
# 11                11  2018-01-05  2018        1      1           5          5
# 14                14  2018-01-08  2018        1      1           8          1
# 15                15  2018-01-09  2018        1      1           9          2
# ...              ...         ...   ...      ...    ...         ...        ...
# 29193769    29193769  2022-03-31  2022        1      3          31          4
# 29193771    29193771  2022-03-31  2022        1      3          31          4
# 29193774    29193774  2022-03-31  2022        1      3          31          4
# 29193776    29193776  2022-03-19  2022        1      3          19          6
# 29193778    29193778  2022-03-17  2022        1      3          17          4
#
# ...

# %%
train = train_val.sample(frac=0.7)

# %%
val = train_val[~train_val.index.isin(train.index)]

# %%
test.shape
# Out:
# (8758135, 25)

# %%
train.shape
# Out:
# (14304953, 25)

# %%
val.shape
# Out:
# (6130694, 25)

# %%
test.to_csv('../raw_data/test.csv', index = False)
train.to_csv('../raw_data/train.csv', index = False)
val.to_csv('../raw_data/val.csv', index = False)

# %%
train_100k = train.sample(100000)
train_100k.to_csv('../raw_data/train_100k.csv', index = False)

val_100k = val.sample(100000)
val_100k.to_csv('../raw_data/val_100k.csv', index = False)

# %%
train_100k
# Out:
#           Unnamed: 0  FlightDate  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 4007400      4007400  2018-06-12  2018        2      6          12          2
# 20873462    20873462  2021-11-21  2021        4     11          21          7
# 17189842    17189842  2020-08-27  2020        3      8          27          4
# 835979        835979  2018-10-06  2018        4     10           6          6
# 13684447    13684447  2019-01-28  2019        1      1          28          1
# ...              ...         ...   ...      ...    ...         ...        ...
# 22915774    22915774  2021-07-11  2021        3      7          11          7
# 1634670      1634670  2018-11-25  2018        4     11          25          7
# 23905565    23905565  2021-02-22  2021        1      2          22          1
# 7043874      7043874  2019-08-25  2019        3      8          25          7
# 18452739    18452739  2020-11-23  2020        4     11          23          1
#
# ...
